# %% [markdown]
# ## Limpieza de datos

# %%
import pandas as pd
import numpy as np



archivo = r"C:\Users\andre\OneDrive\cosas de la universidad\Uniandes\VIII\Analitica comp\Proyecto\proyecto1-secop-agencia-logistica\02-ingenieria-datos\SECOP_II_-_Contratos_Electrónicos_20260912.csv"

df = pd.read_csv(archivo)
print(f"Filas: {df.shape[0]:,} | Columnas: {df.shape[1]}")
df.head()
# Out:
# Filas: 8,051 | Columnas: 85
#                                Nombre Entidad  Nit Entidad  \
# 0  AGENCIA LOGISTICA DE LAS FUERZAS MILITARES  899.999.162
# 1  AGENCIA LOGISTICA DE LAS FUERZAS MILITARES  899.999.162
# 2  AGENCIA LOGISTICA DE LAS FUERZAS MILITARES  899.999.162
# 3  AGENCIA LOGISTICA DE LAS FUERZAS MILITARES  899.999.162
# 4  AGENCIA LOGISTICA DE LAS FUERZAS MILITARES  899.999.162
#
#                  Departamento  Ciudad               Localización     Orden  \
# 0  Distrito Capital de Bogotá  Bogotá  Colombia, Bogotá,  Bogotá  Nacional
# 1  Distrito Capital de Bogotá  Bogotá  Colombia, Bogotá,  Bogotá  Nacional
# 2  Distrito Capital de Bogotá  Bogotá  Colombia, Bogotá,  Bogotá  Nacional
# 3  Distrito Capital de Bogotá  Bogotá  Colombia, Bogotá,  Bogotá  Nacional
# 4  Distrito Capital de Bogotá  Bogotá  Colombia, Bogotá,  Bogotá  Nacional
#
#     Sector       Rama Entidad Centralizada  Proceso de Compra  ...  \
# 0  defensa  Ejecutivo         Centralizada  CO1.BDOS.10448103  ...
# 1  defensa  Ejecutivo         Centralizada    CO1.BDOS.457665  ...
# 2  defensa  Ejecutivo         Centralizada   CO1.BDOS.2013851  ...
# 3  defensa  Ejecutivo         Centralizada   CO1.BDOS.8720928  ...
# 4  defensa  Ejecutivo         Centralizada   CO1.BDOS.1601337  ...
#
#   Número de documento Ordenador del gasto                Nombre supervisor  \
# 0                                74083888  Luis Alberto Montealegre Castro
# 1                             No definido                      No definido
# 2                                91067370                  Julian Almeciga
# 3                                79415117          LUIS MIGUEL POLO ACOSTA
# 4                                19462097                      No definido
#
#   Tipo de documento supervisor Número de documento supervisor  \
# 0         Cédula de Ciudadanía                     1014237586
# 1                  No definido                    No definido
# 2         Cédula de Ciudadanía                     1013599327
# 3         Cédula de Ciudadanía                        8786297
# 4                  No definido                    No definido
#
#   Nombre Ordenador de Pago Tipo de documento Ordenador de Pago  \
# 0              No definido                         No definido
# 1              No definido                         No definido
# 2              No definido                         No definido
# 3       RICARDO JEREZ SOTO                Cédula de Ciudadanía
# 4              No definido                         No definido
#
#   Número de documento Ordenador de Pago Documentos Tipo  \
# 0                           No definido              No
# 1                           No definido              No
# 2                           No definido              No
# 3                              79415117              No
# 4                           No definido              No
#
#   Descripcion Documentos Tipo  \
# 0                 No definido
# 1                 No definido
# 2                 No definido
# 3                 No definido
# 4                 No definido
#
#                  Dirección de ejecución del contrato
# 0  calle 14 sur N° 11-295 URB. EL PROGRESO VIA BR...
# 1  CALLE 95 13-08\nDistrito Capital de Bogotá\nCO...
# 2  DEPARTAMENTO DE BUCEO Y SALVAMENTO AV. SN MART...
# 3  Calle 30 Vía a Malambo; al lado del Batallón V...
# 4  CALLE 95 No. 13-08\nBogotá\nDistrito Capital d...
#
# [5 rows x 85 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8051 entries, 0 to 8050
# Data columns (total 85 columns):
#  #   Column                                                                        Non-Null Count  Dtype
# ---  ------                                                                        --------------  -----
#  0   Nombre Entidad                                                                8051 non-null   object
#  1   Nit Entidad                                                                   8051 non-null   object
#  2   Departamento                                                                  8051 non-null   object
#  3   Ciudad                                                                        8051 non-null   object
#  4   Localización                                                                  8051 non-null   object
#  5   Orden                                                                         8051 non-null   object
#  6   Sector                                                                        8051 non-null   object
#  7   Rama                                                                          8051 non-null   object
#  8   Entidad Centralizada                                                          8051 non-null   object
#  9   Proceso de Compra                                                             8051 non-null   object
#  10  ID Contrato                                                                   8051 non-null   object
#  11  Referencia del Contrato                                                       8051 non-null   object
#  12  Estado Contrato                                                               8051 non-null   object
#  13  Codigo de Categoria Principal                                                 8051 non-null   object
#  14  Descripcion del Proceso                                                       8051 non-null   object
#  15  Tipo de Contrato                                                              8051 non-null   object
#  16  Modalidad de Contratacion                                                     8051 non-null   object
#  17  Justificacion Modalidad de Contratacion                                       8051 non-null   object
#  18  Fecha de Firma                                                                7360 non-null   object
#  19  Fecha de Inicio del Contrato                                                  7543 non-null   object
#  20  Fecha de Fin del Contrato                                                     7848 non-null   object
#  21  Condiciones de Entrega                                                        8051 non-null   object
#  22  TipoDocProveedor                                                              8051 non-null   object
#  23  Documento Proveedor                                                           8051 non-null   object
#  24  Proveedor Adjudicado                                                          8051 non-null   object
#  25  Es Grupo                                                                      8051 non-null   object
#  26  Es Pyme                                                                       8051 non-null   object
#  27  Habilita Pago Adelantado                                                      8051 non-null   object
#  28  Liquidación                                                                   8051 non-null   object
#  29  Obligación Ambiental                                                          8051 non-null   object
#  30  Obligaciones Postconsumo                                                      8051 non-null   object
#  31  Reversion                                                                     8051 non-null   object
#  32  Origen de los Recursos                                                        8051 non-null   object
#  33  Destino Gasto                                                                 8051 non-null   object
#  34  Valor del Contrato                                                            8051 non-null   object
#  35  Valor de pago adelantado                                                      8051 non-null   object
#  36  Valor Facturado                                                               8051 non-null   object
#  37  Valor Pendiente de Pago                                                       8051 non-null   object
#  38  Valor Pagado                                                                  8051 non-null   object
#  39  Valor Amortizado                                                              8051 non-null   object
#  40  Valor Pendiente de Amortizacion                                               8051 non-null   object
#  41  Valor Pendiente de Ejecucion                                                  8051 non-null   object
#  42  Saldo CDP                                                                     8051 non-null   object
#  43  Saldo Vigencia                                                                8051 non-null   object
#  44  EsPostConflicto                                                               8051 non-null   object
#  45  Dias adicionados                                                              8051 non-null   float64
#  46  Puntos del Acuerdo                                                            8051 non-null   object
#  47  Pilares del Acuerdo                                                           8051 non-null   object
#  48  URLProceso                                                                    8051 non-null   object
#  49  Nombre Representante Legal                                                    8051 non-null   object
#  50  Nacionalidad Representante Legal                                              8051 non-null   object
#  51  Domicilio Representante Legal                                                 8051 non-null   object
#  52  Tipo de Identificación Representante Legal                                    8051 non-null   object
#  53  Identificación Representante Legal                                            8051 non-null   object
#  54  Género Representante Legal                                                    8051 non-null   object
#  55  Presupuesto General de la Nacion – PGN                                        8051 non-null   object
#  56  Sistema General de Participaciones                                            8051 non-null   object
#  57  Sistema General de Regalías                                                   8051 non-null   object
#  58  Recursos Propios (Alcaldías y Gobernaciones)                                  8051 non-null   object
#  59  Recursos de Credito                                                           8051 non-null   object
#  60  Otros Recursos (Especie, Privados, Cooperación, Propios Entidades Autónomas)  8051 non-null   object
#  61  Ultima Actualizacion                                                          6830 non-null   object
#  62  Codigo Entidad                                                                8051 non-null   object
#  63  Codigo Proveedor                                                              8051 non-null   int64
#  64  Fecha Inicio Liquidacion                                                      5354 non-null   object
#  65  Fecha Fin Liquidacion                                                         5358 non-null   object
#  66  Objeto del Contrato                                                           8051 non-null   object
#  67  Duración del contrato                                                         8051 non-null   object
#  68  Nombre del banco                                                              8051 non-null   object
#  69  Tipo de cuenta                                                                8051 non-null   object
#  70  Número de cuenta                                                              8049 non-null   object
#  71  El contrato puede ser prorrogado                                              8051 non-null   object
#  72  Fecha de notificación de prorrogación                                         3092 non-null   object
#  73  Nombre ordenador del gasto                                                    8051 non-null   object
#  74  Tipo de documento Ordenador del gasto                                         8051 non-null   object
#  75  Número de documento Ordenador del gasto                                       8051 non-null   object
#  76  Nombre supervisor                                                             8051 non-null   object
#  77  Tipo de documento supervisor                                                  8051 non-null   object
#  78  Número de documento supervisor                                                8051 non-null   object
#  79  Nombre Ordenador de Pago                                                      8051 non-null   object
#  80  Tipo de documento Ordenador de Pago                                           8051 non-null   object
#  81  Número de documento Ordenador de Pago                                         8051 non-null   object
#  82  Documentos Tipo                                                               8051 non-null   object
#  83  Descripcion Documentos Tipo                                                   8051 non-null   object
#  84  Dirección de ejecución del contrato                                           8051 non-null   object
# dtypes: float64(1), int64(1), object(83)
# memory usage: 5.2+ MB

# %%
# Duplicados
print("Filas totalmente duplicadas:", df.duplicated().sum())
print("IDs de contrato duplicados:", df['ID Contrato'].duplicated().sum())
# Out:
# Filas totalmente duplicadas: 0
# IDs de contrato duplicados: 0

# %%
# Nulos por columna 
nulos = df.isnull().sum().sort_values(ascending=False)
pct = (nulos / len(df) * 100).round(2)
resumen_nulos = pd.DataFrame({'nulos': nulos, 'pct_%': pct})
resumen_nulos[resumen_nulos['nulos'] > 0]
# Out:
#                                        nulos  pct_%
# Fecha de notificación de prorrogación   4959  61.59
# Fecha Inicio Liquidacion                2697  33.50
# Fecha Fin Liquidacion                   2693  33.45
# Ultima Actualizacion                    1221  15.17
# Fecha de Firma                           691   8.58
# Fecha de Inicio del Contrato             508   6.31
# Fecha de Fin del Contrato                203   2.52
# Número de cuenta                           2   0.02

# %%
# Columnas con un único valor 

constantes = [c for c in df.columns if df[c].nunique(dropna=False) == 1]
print(f"{len(constantes)} columnas constantes:")
for c in constantes:
    print(f"  - {c}: {df[c].iloc[0]!r}")
# Out:
# 16 columnas constantes:
#   - Nombre Entidad: 'AGENCIA LOGISTICA DE LAS FUERZAS MILITARES'
#   - Nit Entidad: '899.999.162'
#   - Departamento: 'Distrito Capital de Bogotá'
#   - Ciudad: 'Bogotá'
#   - Localización: 'Colombia, Bogotá,  Bogotá'
#   - Orden: 'Nacional'
#   - Sector: 'defensa'
#   - Rama: 'Ejecutivo'
#   - Entidad Centralizada: 'Centralizada'
#   - Reversion: 'No'
#   - Valor Amortizado: '$0'
#   - Puntos del Acuerdo: 'No aplica'
#   - Pilares del Acuerdo: 'No aplica'
#   - Sistema General de Participaciones: '$0'
#   - Sistema General de Regalías: '$0'
#   - Codigo Entidad: '700.985.252'

# %%
cols_valor = [c for c in df.columns if c.startswith('Valor') or 'Saldo' in c]
df[cols_valor].head(5)
# Out:
#   Valor del Contrato Valor de pago adelantado Valor Facturado  \
# 0        $75.000.000                       $0              $0
# 1         $5.848.992                       $0              $0
# 2         $1.392.300                       $0      $1.392.300
# 3        $34.200.000                       $0              $0
# 4    $11.496.000.000                       $0              $0
#
#   Valor Pendiente de Pago Valor Pagado Valor Amortizado  \
# 0             $75.000.000           $0               $0
# 1              $5.848.992           $0               $0
# 2                      $0   $1.392.300               $0
# 3             $34.200.000           $0               $0
# 4         $11.496.000.000           $0               $0
#
#   Valor Pendiente de Amortizacion Valor Pendiente de Ejecucion  \
# 0                              $0                  $75.000.000
# 1                              $0                   $5.848.992
# 2                              $0                           $0
# 3                              $0                  $34.200.000
# 4                              $0              $11.496.000.000
#
#         Saldo CDP Saldo Vigencia
# 0     $75.000.000              0
# 1    $681.043.492              0
# 2      $2.415.585              0
# 3     $35.700.000              0
# 4  $6.500.000.000  4.996.000.000

# %%
# Formato fechas
cols_fecha = [c for c in df.columns if c.lower().startswith('fecha')]
for c in cols_fecha:
    print(c, "-", df[c].dropna().unique()[:2])
# Out:
# Fecha de Firma - ['07/31/2026' '08/06/2018']
# Fecha de Inicio del Contrato - ['08/26/2026' '07/27/2018']
# Fecha de Fin del Contrato - ['12/31/2026' '08/13/2018']
# Fecha Inicio Liquidacion - ['2026 Dec 31 12:00:00 AM' '2022 Jan 11 12:00:00 AM']
# Fecha Fin Liquidacion - ['2027 Apr 30 12:00:00 AM' '2022 May 11 12:00:00 AM']
# Fecha de notificación de prorrogación - ['2026 Dec 21 12:00:00 AM' '2018 Aug 31 12:00:00 AM']

# %%
df['Duración del contrato'].value_counts().head(10)
# Out:
# Duración del contrato
# Dia(s)         1990
# No definido    1283
# 9 Mes(es)       332
# 8 Mes(es)       309
# 4 Mes(es)       289
# 10 Mes(es)      281
# 5 Mes(es)       267
# 3 Mes(es)       263
# 7 Mes(es)       251
# 6 Mes(es)       244
# Name: count, dtype: int64

# %%
df['Estado Contrato'].value_counts()
# Out:
# Estado Contrato
# terminado            3153
# Cerrado              3128
# Modificado            573
# En ejecución          447
# Cancelado             301
# Borrador              229
# enviado Proveedor     134
# Aprobado               56
# En aprobación          27
# cedido                  2
# Suspendido              1
# Name: count, dtype: int64

# %%
df['Nombre del banco'].value_counts().head(12)
# Out:
# Nombre del banco
# No definido           3393
# BANCOLOMBIA           1037
# Bancolombia            414
# DAVIVIENDA             378
# BANCO DE BOGOTA        356
# bancolombia            264
# BBVA                   240
# BANCO BBVA             202
# BANCO POPULAR          193
# Banco Davivienda       113
# BANCO DAVIVIENDA       100
# BANCO DE OCCIDENTE      95
# Name: count, dtype: int64

# %% [markdown]
# ## Limpieza de datos

# %% [markdown]
# Estandarizar los nombres de las columnas

# %%
import unicodedata
import re

def a_snake_case(texto):
    texto = unicodedata.normalize('NFKD', texto).encode('ascii', 'ignore').decode('ascii')
    texto = re.sub(r'[^0-9a-zA-Z]+', '_', texto).strip('_')
    return texto.lower()

df_clean = df.copy()
mapa_columnas = {c: a_snake_case(c) for c in df_clean.columns}
df_clean = df_clean.rename(columns=mapa_columnas)
df_clean.columns.tolist()[:15]
# Out:
# ['nombre_entidad',
#  'nit_entidad',
#  'departamento',
#  'ciudad',
#  'localizacion',
#  'orden',
#  'sector',
#  'rama',
#  'entidad_centralizada',
#  'proceso_de_compra',
#  'id_contrato',
#  'referencia_del_contrato',
#  'estado_contrato',
#  'codigo_de_categoria_principal',
#  'descripcion_del_proceso']

# %% [markdown]
#  Transformar variables monetarias de formato $ a formato float

# %%
cols_monetarias = [c for c in df_clean.columns if c.startswith('valor') or 'saldo' in c]
print(cols_monetarias)

def limpiar_moneda(serie):
    return (
        serie.astype(str)
        .str.replace('$', '', regex=False)
        .str.replace('.', '', regex=False)
        .str.replace(',', '.', regex=False)  # por si aparecen decimales con coma
        .str.strip()
        .replace({'': np.nan, 'nan': np.nan})
        .astype(float)
    )

for c in cols_monetarias:
    df_clean[c] = limpiar_moneda(df_clean[c])

df_clean[cols_monetarias].describe().T
# Out:
# ['valor_del_contrato', 'valor_de_pago_adelantado', 'valor_facturado', 'valor_pendiente_de_pago', 'valor_pagado', 'valor_amortizado', 'valor_pendiente_de_amortizacion', 'valor_pendiente_de_ejecucion', 'saldo_cdp', 'saldo_vigencia']
#                                   count          mean           std  \
# valor_del_contrato               8051.0  1.090707e+11  7.837826e+12
# valor_de_pago_adelantado         8051.0  1.852309e+06  1.087890e+08
# valor_facturado                  8051.0  2.699280e+08  4.272421e+09
# valor_pendiente_de_pago          8051.0  1.088219e+11  7.837828e+12
# valor_pagado                     8051.0  2.487644e+08  4.164953e+09
# valor_amortizado                 8051.0  0.000000e+00  0.000000e+00
# valor_pendiente_de_amortizacion  8051.0  1.852309e+06  1.087890e+08
# valor_pendiente_de_ejecucion     8051.0  5.816150e+08  7.004481e+09
# saldo_cdp                        8051.0  9.121753e+08  2.149798e+10
# saldo_vigencia                   8051.0  2.800076e+08  3.860956e+09
#
#                                          min         25%          50%  \
# valor_del_contrato                       0.0  16000000.0  54653421.81
# valor_de_pago_adelantado                 0.0         0.0         0.00
# valor_facturado                          0.0         0.0  21604688.00
# valor_pendiente_de_pago         -179993745.0       313.5    672000.00
# valor_pagado                             0.0         0.0  17243100.00
# valor_amortizado                         0.0         0.0         0.00
# valor_pendiente_de_amortizacion          0.0         0.0         0.00
# valor_pendiente_de_ejecucion    -179993745.0       310.0    661000.00
# saldo_cdp                                0.0  10000000.0  45000000.00
# saldo_vigencia                           0.0         0.0         0.00
#
#                                          75%           max
# valor_del_contrato               180000000.0  6.760000e+14
# valor_de_pago_adelantado                 0.0  8.363229e+09
# valor_facturado                   90000000.0  3.450987e+11
# valor_pendiente_de_pago           33580085.0  6.760000e+14
# valor_pagado                      85050450.0  3.450987e+11
# valor_amortizado                         0.0  0.000000e+00
# valor_pendiente_de_amortizacion          0.0  8.363229e+09
# valor_pendiente_de_ejecucion      33517252.0  2.351593e+11
# saldo_cdp                        170000000.0  1.831003e+12
# saldo_vigencia                           0.0  1.113677e+11

# %% [markdown]
# Poner un solo formato de fechas

# %%
cols_fecha_mdy = ['fecha_de_firma', 'fecha_de_inicio_del_contrato', 'fecha_de_fin_del_contrato']
cols_fecha_texto = [
    'ultima_actualizacion', 'fecha_inicio_liquidacion', 'fecha_fin_liquidacion',
    'fecha_de_notificacion_de_prorrogacion'
]

for c in cols_fecha_mdy:
    df_clean[c] = pd.to_datetime(df_clean[c], format='%m/%d/%Y', errors='coerce')

for c in cols_fecha_texto:
    df_clean[c] = pd.to_datetime(
        df_clean[c].str.replace(' 12:00:00 AM', '', regex=False),
        format='%Y %b %d', errors='coerce'
    )

df_clean[cols_fecha_mdy + cols_fecha_texto].dtypes
# Out:
# fecha_de_firma                           datetime64[ns]
# fecha_de_inicio_del_contrato             datetime64[ns]
# fecha_de_fin_del_contrato                datetime64[ns]
# ultima_actualizacion                     datetime64[ns]
# fecha_inicio_liquidacion                 datetime64[ns]
# fecha_fin_liquidacion                    datetime64[ns]
# fecha_de_notificacion_de_prorrogacion    datetime64[ns]
# dtype: object

# %% [markdown]
# Convertir duracion de str a numero

# %%
def parsear_duracion(texto):
    texto = str(texto).strip()
    m = re.match(r'^(\d+)\s+(Dia|Mes)', texto)
    if not m:
        return np.nan, np.nan
    cantidad, unidad = int(m.group(1)), m.group(2)
    dias = cantidad * 30 if unidad == 'Mes' else cantidad
    return cantidad, unidad

parsed = df_clean['duracion_del_contrato'].apply(parsear_duracion)
df_clean['duracion_valor'] = parsed.apply(lambda x: x[0])
df_clean['duracion_unidad'] = parsed.apply(lambda x: x[1])
df_clean['duracion_dias'] = df_clean.apply(
    lambda r: r['duracion_valor'] * 30 if r['duracion_unidad'] == 'Mes' else r['duracion_valor'],
    axis=1
)
df_clean[['duracion_del_contrato', 'duracion_valor', 'duracion_unidad', 'duracion_dias']].head(8)
# Out:
#   duracion_del_contrato  duracion_valor duracion_unidad  duracion_dias
# 0             5 Mes(es)             5.0             Mes          150.0
# 1                Dia(s)             NaN             NaN            NaN
# 2            162 Dia(s)           162.0             Dia          162.0
# 3             45 Dia(s)            45.0             Dia           45.0
# 4            120 Dia(s)           120.0             Dia          120.0
# 5                Dia(s)             NaN             NaN            NaN
# 6             4 Mes(es)             4.0             Mes          120.0
# 7             4 Mes(es)             4.0             Mes          120.0

# %% [markdown]
# Pasar campos si/no a booleanos

# %%
cols_si_no = [
    'es_grupo', 'es_pyme', 'habilita_pago_adelantado', 'liquidacion',
    'obligacion_ambiental', 'obligaciones_postconsumo', 'reversion',
    'espostconflicto', 'el_contrato_puede_ser_prorrogado'
]
cols_si_no = [c for c in cols_si_no if c in df_clean.columns]

mapa_bool = {'Si': True, 'No': False}
for c in cols_si_no:
    df_clean[c] = df_clean[c].map(mapa_bool)

df_clean[cols_si_no].mean(numeric_only=True).round(3)  # proporción de "Si" por columna
# Out:
# es_grupo                            0.028
# es_pyme                             0.712
# liquidacion                         0.665
# obligacion_ambiental                0.021
# obligaciones_postconsumo            0.002
# reversion                           0.000
# espostconflicto                     0.001
# el_contrato_puede_ser_prorrogado    0.443
# dtype: float64
